# %%
from keras.models import Sequential
from keras.layers import Dense

import cPickle
import gzip

# Third-party libraries
import numpy as np

def load_data():
    f = gzip.open('mnist.pkl.gz', 'rb')
    training_data, validation_data, test_data = cPickle.load(f)
    f.close()
    return (training_data, validation_data, test_data)

def load_data_wrapper():
    tr_d, va_d, te_d = load_data()
    training_inputs = [np.reshape(x, (784,1)) for x in tr_d[0]]
    training_results = [vectorized_result(y) for y in tr_d[1]]
    validation_inputs = [np.reshape(x, (784,1)) for x in va_d[0]]
    test_inputs = [np.reshape(x, (784,1)) for x in te_d[0]]
    test_results= [vectorized_result(y) for y in te_d[1]]
    return (training_inputs,training_results, validation_inputs, va_d[1] , test_inputs, test_results)

def vectorized_result(j):
    e = np.zeros((10, 1))
    e[j] = 1.0
    return e




training,training_answer, validation,validation_answer, test,test_answer = load_data_wrapper()

# creating train data in a array of shape(50000,784)
training_data=np.array(training)
train=training_data.reshape(50000,784)


# creating train answer in a array of shape(50000,10)
train_ans=np.array(training_answer)
train_answer=train_ans.reshape(50000,10)




#do same as you have done for train with validation and test data
validation_data=np.array(validation)
validate=validation_data.reshape(10000,784)


validate_answer=np.array(validation_answer)
validate_answer=validate_answer.reshape(10000,1)


test=np.array(test)
test=test.reshape(10000,784)


test_answer=np.array(test_answer)
test_answer=test_answer.reshape(10000,10)

#Architecture or Model
model=Sequential()
model.add(Dense(250,input_dim=784,activation="relu"))
model.add(Dense(10,activation="softmax"))


model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

#Training
model.fit(train,train_answer,epochs=20,batch_size=50000)

#Validation
scores=model.evaluate(test,test_answer)
print("\n%s : %.2f%%" % (model.metrics_names[1],scores[1]*100))
# Out:
# /home/harsh/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Epoch 1/20
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.3378 - acc: 0.9001
# Epoch 2/20
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.3132 - acc: 0.9001
# Epoch 3/20
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.2949 - acc: 0.9001
# Epoch 4/20
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.2750 - acc: 0.9001
# Epoch 5/20
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.2570 - acc: 0.9013
# Epoch 6/20
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.2382 - acc: 0.9048
# Epoch 7/20
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2198 - acc: 0.9091
# Epoch 8/20
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2026 - acc: 0.9153
# Epoch 9/20
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.1862 - acc: 0.9233
# Epoch 10/20
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.1714 - acc: 0.9315
# Epoch 11/20
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.1579 - acc: 0.9386
# Epoch 12/20
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.1460 - acc: 0.9445
# Epoch 13/20
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.1354 - acc: 0.9500
# Epoch 14/20
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.1260 - acc: 0.9546
# Epoch 15/20
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.1177 - acc: 0.9587
# Epoch 16/20
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.1105 - acc: 0.9619
# Epoch 17/20
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.1043 - acc: 0.9645
# Epoch 18/20
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.0989 - acc: 0.9666
# Epoch 19/20
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.0941 - acc: 0.9684
# Epoch 20/20
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.0898 - acc: 0.9700
# 10000/10000 [==============================] - 1s 73us/step
#
# acc : 97.31%
